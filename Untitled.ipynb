# %% [markdown]
# # Credit Card Fraud Detection

# %% [markdown]
# ## Imports and Data Set

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import datetime as datetime 

# %matplotlib inline

# %%
transactionData = pd.read_csv('f_data.csv', index_col = 'user_id')
ipData = pd.read_csv('ip_country.csv')

# %%
transactionData.head(10)
# Out:
#                  signup_time        purchase_time  purchase_value  \
# user_id
# 22058    2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 333320   2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 1359     2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 150084   2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 221365   2015-07-21 07:09:52  2015-09-09 18:40:53              39
# 159135   2015-05-21 06:03:03  2015-07-09 08:05:14              42
# 50116    2015-08-01 22:40:52  2015-08-27 03:37:57              11
# 360585   2015-04-06 07:35:45  2015-05-25 17:21:14              27
# 159045   2015-04-21 23:38:34  2015-06-02 14:01:54              30
# 182338   2015-01-25 17:49:49  2015-03-23 23:05:42              62
#
#              device_id source browser sex  age    ip_address  class
# user_id
# 22058    QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0
# 333320   EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0
# 1359     YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1
# 150084   ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0
# 221365   NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0
# 159135   ALEYXFXINSXLZ    Ads  Chrome   M   18  2.809315e+09      0
# 50116    IWKVZHJOCLPUR    Ads  Chrome   F   19  3.987484e+09      0
# 360585   HPUCUYLMJBYFW    Ads   Opera   M   34  1.692459e+09      0
# 159045   ILXYDOZIHOOHT    SEO      IE   F   43  3.719094e+09      0
# 182338   NRFFPPHZYFUVC    Ads      IE   M   31  3.416747e+08      0

# %%
len(transactionData.columns)
# Out:
# 10

# %%
transactionData.dtypes
# Out:
# signup_time        object
# purchase_time      object
# purchase_value      int64
# device_id          object
# source             object
# browser            object
# sex                object
# age                 int64
# ip_address        float64
# class               int64
# dtype: object

# %%
transactionData.shape
# Out:
# (151112, 10)

# %%
## checking the nulll status

transactionData.isnull().any()
# Out:
# signup_time       False
# purchase_time     False
# purchase_value    False
# device_id         False
# source            False
# browser           False
# sex               False
# age               False
# ip_address        False
# class             False
# dtype: bool

# %% [markdown]
# ### No Null Values in any of the columns

# %% [markdown]
# ## Keeping a Count of the Fraud Transactions

# %%
transactionData.groupby('class')['sex'].count()
# Out:
# class
# 0    136961
# 1     14151
# Name: sex, dtype: int64

# %%
compareStats = pd.value_counts(transactionData['class'])
plt.figure(figsize=(10,6))

compareStats.plot(kind = 'bar') 
plt.title('Fraud Distribution')

plt.xlabel('Type')
plt.ylabel('Frequency')

plt.style.use('fivethirtyeight')

plt.show()

# %%
fraudTransactions = pd.DataFrame(transactionData[transactionData['class'] == 1])
legitTransactions = pd.DataFrame(transactionData[transactionData['class']== 0])

# %%
fraudTransactions.head()
# Out:
#                  signup_time        purchase_time  purchase_value  \
# user_id
# 1359     2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 171711   2015-01-11 01:51:15  2015-01-11 01:51:16              52
# 59780    2015-01-04 22:32:33  2015-01-16 01:13:43              31
# 151705   2015-01-07 03:44:53  2015-01-07 03:44:54              48
# 345865   2015-02-01 05:59:23  2015-02-20 08:09:10              36
#
#              device_id  source  browser sex  age    ip_address  class
# user_id
# 1359     YSSKYOSJHPPLJ     SEO    Opera   M   53  2.621474e+09      1
# 171711   YPLQGKBAAULUV  Direct       IE   F   35  1.120619e+09      1
# 59780    WUMOBGUCBOXPO     SEO  FireFox   M   36  1.752167e+09      1
# 151705   URHCRIXOMLJMH     SEO   Chrome   F   27  2.836025e+09      1
# 345865   FKQPZUELCRKBL     SEO       IE   M   30  2.740590e+09      1

# %%
legitTransactions.head()
# Out:
#                  signup_time        purchase_time  purchase_value  \
# user_id
# 22058    2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 333320   2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 150084   2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 221365   2015-07-21 07:09:52  2015-09-09 18:40:53              39
# 159135   2015-05-21 06:03:03  2015-07-09 08:05:14              42
#
#              device_id source browser sex  age    ip_address  class
# user_id
# 22058    QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0
# 333320   EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0
# 150084   ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0
# 221365   NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0
# 159135   ALEYXFXINSXLZ    Ads  Chrome   M   18  2.809315e+09      0

# %%
print(fraudTransactions.shape , legitTransactions.shape)
# Out:
# (14151, 10) (136961, 10)

# %% [markdown]
# ### More inferences from the two tables

# %%
fraudTransactions['purchase_value'].describe()    ## the purchase value info
# Out:
# count    14151.000000
# mean        36.993004
# std         18.397654
# min          9.000000
# 25%         22.000000
# 50%         35.000000
# 75%         49.000000
# max        111.000000
# Name: purchase_value, dtype: float64

# %%
pd.value_counts(fraudTransactions['browser'])
# Out:
# Chrome     6069
# IE         3187
# FireFox    2342
# Safari     2225
# Opera       328
# Name: browser, dtype: int64

# %%
fraudTransactions['signup_time'] = pd.to_datetime(transactionData['signup_time'])
fraudTransactions['purchase_time'] = pd.to_datetime(transactionData['purchase_time'])

fraudTransactions['session_duration'] = fraudTransactions['purchase_time'] - fraudTransactions['signup_time']

# %%
fraudTransactions.head(5)
# Out:
#                 signup_time       purchase_time  purchase_value  \
# user_id
# 1359    2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 171711  2015-01-11 01:51:15 2015-01-11 01:51:16              52
# 59780   2015-01-04 22:32:33 2015-01-16 01:13:43              31
# 151705  2015-01-07 03:44:53 2015-01-07 03:44:54              48
# 345865  2015-02-01 05:59:23 2015-02-20 08:09:10              36
#
#              device_id  source  browser sex  age    ip_address  class  \
# user_id
# 1359     YSSKYOSJHPPLJ     SEO    Opera   M   53  2.621474e+09      1
# 171711   YPLQGKBAAULUV  Direct       IE   F   35  1.120619e+09      1
# 59780    WUMOBGUCBOXPO     SEO  FireFox   M   36  1.752167e+09      1
# 151705   URHCRIXOMLJMH     SEO   Chrome   F   27  2.836025e+09      1
# 345865   FKQPZUELCRKBL     SEO       IE   M   30  2.740590e+09      1
#
#         session_duration
# user_id
# 1359     0 days 00:00:01
# 171711   0 days 00:00:01
# 59780   11 days 02:41:10
# 151705   0 days 00:00:01
# 345865  19 days 02:09:47

# %%
fraudTransactions.session_duration.describe()
# Out:
# count                      14151
# mean     28 days 01:17:22.350293
# std      38 days 08:29:48.829766
# min              0 days 00:00:01
# 25%              0 days 00:00:01
# 50%              0 days 00:00:01
# 75%      55 days 10:41:50.500000
# max            119 days 22:52:27
# Name: session_duration, dtype: object

# %%
## graph of the amount per transaction for a fraud 

plt.figure(figsize=(15,8))
plt.hist(fraudTransactions['purchase_value'], bins = 50)

plt.style.use('fivethirtyeight')
plt.show()

# %%
hour_fraud = pd.DataFrame(fraudTransactions['purchase_time'])
hour_fraud['hours'] = hour_fraud['purchase_time'].apply(lambda x : x.time().hour)

# %%
plt.figure(figsize = (15,8))

plt.scatter(hour_fraud.hours, fraudTransactions.purchase_value)
plt.title('Time vs Fraud Amount')
plt.xlabel('Time(only hours)')
plt.ylabel('Amount')

plt.show()

# %%
fraudTransactions.purchase_value.describe()
# Out:
# count    14151.000000
# mean        36.993004
# std         18.397654
# min          9.000000
# 25%         22.000000
# 50%         35.000000
# 75%         49.000000
# max        111.000000
# Name: purchase_value, dtype: float64

# %% [markdown]
# ## Normalising the values of purchase

# %%
purchaseNM = fraudTransactions.purchase_value.apply(lambda x : (x - fraudTransactions.purchase_value.mean())/(fraudTransactions.purchase_value.max() - fraudTransactions.purchase_value.min()) )

# %%
purchaseNM.describe()
# Out:
# count    1.415100e+04
# mean     1.286277e-17
# std      1.803692e-01
# min     -2.744412e-01
# 25%     -1.469902e-01
# 50%     -1.953926e-02
# 75%      1.177156e-01
# max      7.255588e-01
# Name: purchase_value, dtype: float64

# %% [markdown]
# ## Sample Data

# %%
## picking up a chunk of data 

sampleData = transactionData.sample(frac = 0.2 , random_state= 1)

sampleData.shape
# Out:
# (30222, 10)

# %%
pd.value_counts(sampleData['class'])
# Out:
# 0    27351
# 1     2871
# Name: class, dtype: int64

# %%
fraudSample = sampleData[sampleData['class'] == 1]
legitSample = sampleData[sampleData['class'] == 0]

print(fraudSample.shape, legitSample.shape)
# Out:
# (2871, 10) (27351, 10)

# %%
coeff = sampleData.corr()
coeff
# Out:
#                 purchase_value       age  ip_address     class
# purchase_value        1.000000  0.000521   -0.015858  0.002526
# age                   0.000521  1.000000    0.005461  0.004399
# ip_address           -0.015858  0.005461    1.000000 -0.003595
# class                 0.002526  0.004399   -0.003595  1.000000

# %%
q = coeff.index 
q
# Out:
# Index(['purchase_value', 'age', 'ip_address', 'class'], dtype='object')

# %%
plt.figure(figsize=(15,8))

sns.heatmap(sampleData[q].corr(),annot=True)

# %%
outlierFraction  = fraudSample.shape[0] / legitSample.shape[0]

outlierFraction
# Out:
# 0.10496873971701218

# %%
len(fraudSample)/float(len(legitSample))
# Out:
# 0.10496873971701218
